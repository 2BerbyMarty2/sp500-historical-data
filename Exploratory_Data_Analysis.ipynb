# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import shutil

# %%
data_path = "data/all_stocks_5yr.csv"
print("Loading data from:", data_path)
# Out:
# Loading data from: data/all_stocks_5yr.csv
